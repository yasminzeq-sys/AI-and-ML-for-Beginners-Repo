# %% [markdown]
# ### Functions in python

# %% [markdown]
# - user defined functions
#     -
# - built in functions
#     -

# %% [markdown]
# ```python
#
# # creating a function
# def FunctionName(parameters):  # variables that can be used in function
#     #reusable code with the parameters
#     return
#
# FunctionName(arguments) # the actual values that we pass
#
# ```

# %%
# create a function

def GreetStudent():
    print("Hello students! Welcome to the Python Jungle")
    print("Hello students! Welcome to the Python Jungle")
    print("Hello students! Welcome to the Python Jungle")
    print("Hello students! Welcome to the Python Jungle")
    print("Hello students! Welcome to the Python Jungle")
    print("Hello students! Welcome to the Python Jungle")
    print("Hello students! Welcome to the Python Jungle")
    print("Hello students! Welcome to the Python Jungle")
    print("Hello students! Welcome to the Python Jungle")

# %%
e = GreetStudent()
# Out:
# Hello students! Welcome to the Python Jungle
# Hello students! Welcome to the Python Jungle
# Hello students! Welcome to the Python Jungle
# Hello students! Welcome to the Python Jungle
# Hello students! Welcome to the Python Jungle
# Hello students! Welcome to the Python Jungle
# Hello students! Welcome to the Python Jungle
# Hello students! Welcome to the Python Jungle
# Hello students! Welcome to the Python Jungle

# %%
e

# %%
# create a function that gives us the Sum of two numbers

def add(a,b): # parameters of add
    return a + b

# %%
add64 = add(6,4)

print(add64)
# Out:
# 10

# %% [markdown]
# - Built in functions
# - print(),

# %%
print("our arguments to this function are just text!!!! strings!!!")
# Out:
# our arguments to this function are just text!!!! strings!!!
